# %%
pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.8/dist-packages (2.2.0)

# %%
pip install regexp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: regexp in /usr/local/lib/python3.8/dist-packages (0.1)

# %%
pip install bangla_stemmer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bangla_stemmer in /usr/local/lib/python3.8/dist-packages (1.0)

# %%
pip install bltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bltk in /usr/local/lib/python3.8/dist-packages (1.2)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.8/dist-packages (from bltk) (1.15.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from bltk) (1.7.3)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.8/dist-packages (from bltk) (1.21.6)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.8/dist-packages (from bltk) (3.7)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.8/dist-packages (from bltk) (1.0.2)
# Requirement already satisfied: certifi>=2019.11.28 in /usr/local/lib/python3.8/dist-packages (from bltk) (2022.12.7)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.8/dist-packages (from bltk) (1.2.0)
# Requirement already satisfied: sklearn>=0.0 in /usr/local/lib/python3.8/dist-packages (from bltk) (0.0.post1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.4.5->bltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.4.5->bltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.4.5->bltk) (4.64.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->bltk) (3.1.0)

# %%
import pandas as pd
import numpy as np
import regex as re
import pandas as pd
import emoji
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from bltk.langtools import Tokenizer
from bltk.langtools import UgraStemmer
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from bangla_stemmer.stemmer import stemmer
from sklearn.metrics import classification_report
from xgboost import XGBClassifier
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/drive/MyDrive/dataset/younus.csv')
#dataset = pd.read_excel('data.xlsx')
dataset = dataset.dropna()
#dataset = dataset[0:5000]
#dataset = dataset[['comment','label']]
print(len(dataset))
# Out:
# 2011

# %%
dataset
# Out:
#       Unnamed: 0                                             Review  Sentiment
# 0              0  বই টি আমার সংগ্রহে আছে এবং তা আমি পড়েছি। বই টি...          0
# 1              1                     ফালতু বই। শুধু শুধু টাকা নষ্ট।          0
# 2              2  একটু পড়ে দেখতে বলসিলো, একটু পড়লাম। তারপর হড়হড় ...          0
# 3              3  এটা কোন বই? ছিঃ ধিকার জানায়। প্রশাসনের নজর দেয়...          0
# 4              4  প্রিয় রকমারি.কম, দয়া করে বইটি আপনাদের ওয়েবসাইট...          0
# ...          ...                                                ...        ...
# 2006        2006   1 স্টার দেওয়াও বৃথা। মানে ভিডিও বানাইয়া আজকে ...          0
# 2007        2007  তাদের কথা শুনলে মনে হয় তারা এই মনে হয় আশে পাশে...          0
# 2008        2008   এইরকম বই পড়ার চাইতে মুড়ি কিন্না খাওয়াও ভালো। ...          0
# 2009        2009   বোগাস বই। টাকা নষ্ট।\n                       ...          0
# 2010        2010  বইটি ভালো না। শুধু কিনে টাকা নষ্ট করা ছাড়া আর ...          0
#
# [2011 rows x 3 columns]

# %%
bangla_stop_words =["অতএব", "অথচ", "অথবা", "অনুযায়ী", "অনেক", "অনেকে", "অনেকেই", "অন্তত", "অবধি", "অবশ্য", 
"আগামী", "আগে", "আগেই", "আছে", "আজ", "আদ্যভাগে", "আপনার", "আপনি", "আবার", "আমরা", 
"আমাকে", "আমাদের", "আমার", "আমি", "আর", "আরও", "ইত্যাদি", "ইহা", "উচিত", "উনি", "উপর", 
"উপরে", "এ", "এঁদের", "এঁরা", "এই", "এক", "একই", "একজন", "একটা", "একটি", "একবার", "একে", 
"এখন", "এখনও", "এখানে", "এখানেই", "এটা", "এটাই", "এটি", "এত", "এতটাই", "এতে", "এদের", "এবং", 
"এবার", "এমন", "এমনকি", "এর", "এরা", "এলো", "এস", "এসে", "ঐ", "ও", "ওঁদের", "ওঁর", "ওঁরা", 
"ওই", "ওকে", "ওখানে", "ওদের", "ওর", "ওরা", "কখনও", "কত", "কথা", "কবে", "কয়েক", "কয়েকটি", 
"করছে", "করছেন", "করতে", "করবে", "করবেন", "করলে", "করলেন", "করা", "করাই", "করায়", "করার", 
"করি", "করিতে", "করিয়া", "করিয়ে", "করে", "করেই", "করেছিলেন", "করেছে", "করেছেন", "করেন", "কাউকে", 
"কাছ", "কাছে", "কাজ", "কাজে", "কারও", "কারণ", "কি", "কিংবা", "কিছু", "কিছুই", "কিন্তু", "কী", "কে", 
"কেউ", "কেউই", "কেন", "কোন", "কোনও", "কোনো", "ক্ষেত্রে", "খুব", "গিয়ে", "গিয়েছে", "গুলি", "গেছে", 
"গেল", "গেলে", "গোটা", "চলে", "চান", "চায়", "চেয়ে", "ছাড়া", "ছাড়াও", "ছিল", "ছিলেন", "জন", "জনকে", 
"জনের", "জন্য", "জন্যে", "জানতে", "জানা", "জানানো", "জানায়", "জানিয়ে", "জানিয়েছে", "টি", "তখন", 
"তত", "তথা", "তবু", "তবে", "তা", "তাঁকে", "তাঁদের", "তাঁর", "তাঁরা", "তাঁহারা", "তাই", "তাও", "তাকে", "তাতে", 
"তাদের", "তার", "তারপর", "তারা", "তারই", "তাহলে", "তাহা", "তাহাতে", "তাহার", "তিনই", "তিনি", "তিনিও", 
"তুমি", "তুলে", "তেমন", "তো", "তোমার", "থাকবে", "থাকবেন", "থাকা", "থাকায়", "থাকে", "থাকেন", "থেকে", 
"থেকেই", "থেকেও", "দিকে", "দিতে", "দিয়ে", "দিয়েছে", "দিয়েছেন", "দিলেন", "দিয়ে", "দু", "দুটি", "দুটো", 
"দেওয়া", "দেওয়ার", "দেখতে", "দেখা", "দেখে", "দেন", "দেয়", "দেশের", "দ্বারা", "ধরা", "ধরে", 
"নাকি", "নাগাদ", "নানা", "নিজে", "নিজেই", "নিজেদের", "নিজের", "নিতে", "নিয়ে", "নিয়ে", "নেওয়া", 
"নেওয়ার", "পক্ষে", "পর", "পরে", "পরেই", "পরেও", "পর্যন্ত", "পাওয়া", "পারি", "পারে", "পারেন", "পেয়ে", 
"প্রতি", "প্রভৃতি", "প্রায়", "ফলে", "ফিরে", "ফের", "বছর", "বদলে", "বরং", "বলতে", "বলল", "বললেন", "বলা", "বলে", 
"বলেছেন", "বলেন", "বসে", "বহু", "বা", "বাদে", "বার", "বিনা", "বিভিন্ন", "বিশেষ", "বিষয়টি", "বেশ", "ব্যবহার", 
"ব্যাপারে", "ভাবে", "ভাবেই", "মত", "মতো", "মতোই", "মধ্যভাগে", "মধ্যে", "মধ্যেই", "মধ্যেও", "মনে", "মাত্র", "মাধ্যমে", 
"মানুষ", "মানুষের", "মোট", "মোটেই", "যখন", "যত", "যতটা", "যথেষ্ট", "যদি", "যদিও", "যা", "যাঁর", "যাঁরা", "যাওয়া", 
"যাওয়ার", "যাকে", "যাচ্ছে", "যাতে", "যাদের", "যান", "যাবে", "যায়", "যার", "যারা", "যায়", "যিনি", "যে", "যেখানে", 
"যেতে", "যেন", "যেমন", "রকম", "রয়েছে", "রাখা", "রেখে", "শুধু", "শুরু", "সঙ্গে", "সঙ্গেও", "সব", "সবার", "সমস্ত", 
"সম্প্রতি", "সময়", "সহ", "সহিত", "সাথে", "সুতরাং", "সে", "সেই", "সেখান", "সেখানে", "সেটা", "সেটাই", "সেটাও", "সেটি", 
"স্পষ্ট", "স্বয়ং", "হইতে", "হইবে", "হইয়া", "হওয়া", "হওয়ায়", "হওয়ার", "হচ্ছে", "হত", "হতে", "হতেই", "হন", "হবে", 
"হবেন", "হয়", "হয়তো", "হয়নি", "হয়ে", "হয়েই", "হয়েছিল", "হয়েছে", "হয়েছেন", "হল", "হলে", "হলেই", "হলেও", "হলো", 
"হিসাবে", "হিসেবে", "হৈলে", "হোক", "হয়", "হয়ে", "হয়েছে", "অর্থাৎ", "অন্য", "অনুযায়ী", "অর্ধভাগে", "এসো", "কয়েক", 
"কয়েকটি", "করিয়ে", "করিয়া", "করায়", "গিয়ে", "গিয়েছে", "ছাড়া", "ছাড়াও", "থাকায়", "দিয়েছে", "দিয়েছেন", "দেয়", "দেওয়া", 
"দেওয়ার", "নেওয়ার", "পাওয়া", "পেয়ে", "প্রায়", "বিষয়টি", "যাওয়া", "যাওয়ার", "রয়েছে", "স্বয়ং", "হৈতে", "হইয়া", "হয়েছিল", 
"হয়েছেন", "হয়নি", "হয়েই", "হয়তো", "হওয়া", "হওয়ার", "হওয়ায়", "জানায়", "জাানিয়ে", "জানিয়েছে", "চায়", "চেয়ে", "উত্তর", 
"এমনি", "কেমনে", "কোটি", "চার", "চালু", "চেষ্টা", "দিন", "দুই", "নতুন", "পাঁচ", "প্রথম", "প্রাথমিক", "বক্তব্য", "বন", "বেশি", 
"লক্ষ", "সাধারণ", "সামনে", "হাজার"]
names = ['বাংলাদেশের','ভারত','বাংলাদেশ','তাহসান','মিথিলা','সৃজিত','তাহসানের',
        'আয়রা','আব্দুল লতিফ','আরে','তাহসিন','শাকিব','জয়','রুবেল','দিঘীকে',
         'দিঘি','দীঘির','দিগি','জোলিল','জলিল','অনন্ত','শাকিব','খান','তাহসিরেশন',
         'অপুকে','অপুর','সাকিব','অপু','নাহিদ','আজহারি','জলিল','জিহাদি',
        'শ্রীজিৎ','অনন্ত ','','','','','','']
stop_words_for_own_dataset = ['আ‌মি','ভারতে','দে‌খছি','তোর','কারন',
                              'বুঝা','একদিন','মানে','গেলো','হুম','রাখে',
                              'কেমন','ই','টু','তো','কেমন','ওটা',
                              'মেয়েটাকে','মার','স্বামীর','নাম','তোমরা','দাদা',
                              'মহিলা','টা','চাই','টাও','র','টা','এদেরকে','র্থ',
                              'ভাই','ভাইয়া','হজুর','আপ্নে','এইটা','ু','তারে',
                              'তুই','তাসনিম','রে','ন','তুমার','তোমারে','কইরো',
                              'আপনাকে','নকে','ল','থা','র','লোক','ব','জয়ের',
                              'র','ভাইয়া','ভারত','ধর্ষকের','পোশাক','ধর্ষন',
                              'ধর্ষনের','ধর্ষন','ধর্ষক','','','']

# %%
corpus = []
#stemmer = UgraStemmer()
stmr = stemmer.BanglaStemmer()
for index,value in dataset.iterrows():
    text = str(value['Review'])
    text = re.sub(r'https?:\/\/\S+','',text) #removing hyperlinks
    text = re.sub("[\.\,\!\?\:\;\-\=।*/+-@#$%^&()]", " ", text)
    text = re.sub("[A-Za-z]"," ",text)
    text = re.sub("[0-9]"," ",text)
    text = re.sub("[০-৯]"," ",text)
    text = text.replace("'", "")
    text = text.replace('"', '')
    # text = emoji.get_emoji_regexp().sub(r'', text)
      
    temp = []
    tokens = Tokenizer().word_tokenizer(text)
    for word in tokens:
        if word not in bangla_stop_words:
            if word not in stop_words_for_own_dataset:
                if word not in names:
                    temp.append(word)
    
    text = ' '.join(temp)
    
#     temp = []
#     tokens = Tokenizer().word_tokenizer(text)
#     for word in tokens:
#         stm = stmr.stem(word)
#         temp.append(stm)
#     text = ' '.join(temp)
    
#     tokens = Tokenizer().word_tokenizer(text)
#     stem = stemmer.stem(tokens)
#     text = ' '.join(stem)
    
    text = text.strip()
    corpus.append(text)

# %%
corpus

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
x = tfidf.fit_transform(corpus).toarray()

# %%
y = dataset['Sentiment'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 1)

# %%
x_train.shape
# Out:
# (1508, 1716)

# %%
o = 0
for i in y_test:
    if i == 1:
        o = o + 1
print(o)
# Out:
# 232

# %%
## multinomial naive bayes for tf-idf

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
ann = Sequential()

# %%
#Add the input layer and the first hidden layer
ann.add(Dense(units = 64,activation='relu',input_dim = 1716))
#Add the second hidden layer
ann.add(Dense(units = 64,activation='relu'))
#Add the output layer
ann.add(Dense(units = 1,activation='sigmoid'))

# %%
#Compile the ANN
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
ann.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                109888
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 114,113
# Trainable params: 114,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
ann.fit(x_train,y_train,validation_split=.3,batch_size=100,epochs=100)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 23ms/step - loss: 0.6907 - accuracy: 0.5517 - val_loss: 0.6839 - val_accuracy: 0.7108
# Epoch 2/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6718 - accuracy: 0.8114 - val_loss: 0.6634 - val_accuracy: 0.8124
# Epoch 3/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6324 - accuracy: 0.8853 - val_loss: 0.6188 - val_accuracy: 0.8300
# Epoch 4/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5544 - accuracy: 0.9137 - val_loss: 0.5422 - val_accuracy: 0.8477
# Epoch 5/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4378 - accuracy: 0.9280 - val_loss: 0.4505 - val_accuracy: 0.8543
# Epoch 6/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3145 - accuracy: 0.9384 - val_loss: 0.3834 - val_accuracy: 0.8411
# Epoch 7/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.2255 - accuracy: 0.9441 - val_loss: 0.3572 - val_accuracy: 0.8411
# Epoch 8/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1715 - accuracy: 0.9545 - val_loss: 0.3564 - val_accuracy: 0.8477
# Epoch 9/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1394 - accuracy: 0.9583 - val_loss: 0.3679 - val_accuracy: 0.8477
# Epoch 10/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1178 - accuracy: 0.9668 - val_loss: 0.3822 - val_accuracy: 0.8411
# Epoch 11/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1031 - accuracy: 0.9678 - val_loss: 0.4006 - val_accuracy: 0.8278
# Epoch 12/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0917 - accuracy: 0.9716 - val_loss: 0.4143 - val_accuracy: 0.8366
# Epoch 13/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0841 - accuracy: 0.9716 - val_loss: 0.4299 - val_accuracy: 0.8322
# Epoch 14/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0773 - accuracy: 0.9763 - val_loss: 0.4473 - val_accuracy: 0.8366
# Epoch 15/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0719 - accuracy: 0.9782 - val_loss: 0.4625 - val_accuracy: 0.8366
# Epoch 16/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0673 - accuracy: 0.9791 - val_loss: 0.4757 - val_accuracy: 0.8300
# Epoch 17/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0634 - accuracy: 0.9791 - val_loss: 0.4906 - val_accuracy: 0.8322
# Epoch 18/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0602 - accuracy: 0.9791 - val_loss: 0.5066 - val_accuracy: 0.8256
# Epoch 19/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0578 - accuracy: 0.9801 - val_loss: 0.5191 - val_accuracy: 0.8212
# Epoch 20/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0553 - accuracy: 0.9801 - val_loss: 0.5320 - val_accuracy: 0.8212
# Epoch 21/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0520 - accuracy: 0.9801 - val_loss: 0.5482 - val_accuracy: 0.8146
# Epoch 22/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0508 - accuracy: 0.9810 - val_loss: 0.5604 - val_accuracy: 0.8190
# Epoch 23/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0479 - accuracy: 0.9801 - val_loss: 0.5771 - val_accuracy: 0.8124
# Epoch 24/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0465 - accuracy: 0.9801 - val_loss: 0.5881 - val_accuracy: 0.8212
# Epoch 25/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0453 - accuracy: 0.9810 - val_loss: 0.6034 - val_accuracy: 0.8124
# Epoch 26/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0437 - accuracy: 0.9820 - val_loss: 0.6161 - val_accuracy: 0.8079
# Epoch 27/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0427 - accuracy: 0.9820 - val_loss: 0.6258 - val_accuracy: 0.8079
# Epoch 28/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0413 - accuracy: 0.9810 - val_loss: 0.6373 - val_accuracy: 0.7991
# Epoch 29/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0414 - accuracy: 0.9820 - val_loss: 0.6492 - val_accuracy: 0.8102
# Epoch 30/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0399 - accuracy: 0.9820 - val_loss: 0.6635 - val_accuracy: 0.8079
# Epoch 31/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0387 - accuracy: 0.9820 - val_loss: 0.6699 - val_accuracy: 0.8013
# Epoch 32/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0384 - accuracy: 0.9801 - val_loss: 0.6823 - val_accuracy: 0.8057
# Epoch 33/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0375 - accuracy: 0.9820 - val_loss: 0.6931 - val_accuracy: 0.8079
# Epoch 34/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0369 - accuracy: 0.9801 - val_loss: 0.7021 - val_accuracy: 0.8013
# Epoch 35/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0359 - accuracy: 0.9820 - val_loss: 0.7141 - val_accuracy: 0.8057
# Epoch 36/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0357 - accuracy: 0.9820 - val_loss: 0.7201 - val_accuracy: 0.7991
# Epoch 37/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0349 - accuracy: 0.9810 - val_loss: 0.7295 - val_accuracy: 0.8035
# Epoch 38/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0346 - accuracy: 0.9820 - val_loss: 0.7366 - val_accuracy: 0.7991
# Epoch 39/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0348 - accuracy: 0.9810 - val_loss: 0.7491 - val_accuracy: 0.8057
# Epoch 40/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0350 - accuracy: 0.9829 - val_loss: 0.7530 - val_accuracy: 0.7991
# Epoch 41/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0332 - accuracy: 0.9848 - val_loss: 0.7651 - val_accuracy: 0.8057
# Epoch 42/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0331 - accuracy: 0.9829 - val_loss: 0.7701 - val_accuracy: 0.8035
# Epoch 43/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0333 - accuracy: 0.9839 - val_loss: 0.7779 - val_accuracy: 0.7991
# Epoch 44/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0335 - accuracy: 0.9829 - val_loss: 0.7907 - val_accuracy: 0.8035
# Epoch 45/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0329 - accuracy: 0.9867 - val_loss: 0.7899 - val_accuracy: 0.8035
# Epoch 46/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0322 - accuracy: 0.9848 - val_loss: 0.7996 - val_accuracy: 0.8035
# Epoch 47/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0317 - accuracy: 0.9829 - val_loss: 0.8077 - val_accuracy: 0.7991
# Epoch 48/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0311 - accuracy: 0.9867 - val_loss: 0.8127 - val_accuracy: 0.8035
# Epoch 49/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0309 - accuracy: 0.9839 - val_loss: 0.8228 - val_accuracy: 0.7991
# Epoch 50/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0319 - accuracy: 0.9848 - val_loss: 0.8312 - val_accuracy: 0.8013
# Epoch 51/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0301 - accuracy: 0.9858 - val_loss: 0.8340 - val_accuracy: 0.8013
# Epoch 52/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0309 - accuracy: 0.9801 - val_loss: 0.8431 - val_accuracy: 0.7991
# Epoch 53/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0300 - accuracy: 0.9858 - val_loss: 0.8466 - val_accuracy: 0.7991
# Epoch 54/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0305 - accuracy: 0.9810 - val_loss: 0.8566 - val_accuracy: 0.7991
# Epoch 55/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0297 - accuracy: 0.9839 - val_loss: 0.8638 - val_accuracy: 0.7947
# Epoch 56/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0297 - accuracy: 0.9839 - val_loss: 0.8717 - val_accuracy: 0.7925
# Epoch 57/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0301 - accuracy: 0.9867 - val_loss: 0.8756 - val_accuracy: 0.7991
# Epoch 58/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0289 - accuracy: 0.9848 - val_loss: 0.8828 - val_accuracy: 0.7903
# Epoch 59/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0304 - accuracy: 0.9829 - val_loss: 0.8876 - val_accuracy: 0.7969
# Epoch 60/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0291 - accuracy: 0.9839 - val_loss: 0.8887 - val_accuracy: 0.7991
# Epoch 61/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0288 - accuracy: 0.9867 - val_loss: 0.8992 - val_accuracy: 0.7903
# Epoch 62/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0291 - accuracy: 0.9839 - val_loss: 0.9044 - val_accuracy: 0.7925
# Epoch 63/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0284 - accuracy: 0.9829 - val_loss: 0.9058 - val_accuracy: 0.7991
# Epoch 64/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0289 - accuracy: 0.9858 - val_loss: 0.9126 - val_accuracy: 0.7991
# Epoch 65/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0292 - accuracy: 0.9810 - val_loss: 0.9242 - val_accuracy: 0.7903
# Epoch 66/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0282 - accuracy: 0.9848 - val_loss: 0.9213 - val_accuracy: 0.7947
# Epoch 67/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0286 - accuracy: 0.9858 - val_loss: 0.9274 - val_accuracy: 0.7991
# Epoch 68/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0284 - accuracy: 0.9820 - val_loss: 0.9333 - val_accuracy: 0.7925
# Epoch 69/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0281 - accuracy: 0.9858 - val_loss: 0.9376 - val_accuracy: 0.7947
# Epoch 70/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0281 - accuracy: 0.9858 - val_loss: 0.9424 - val_accuracy: 0.7925
# Epoch 71/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0279 - accuracy: 0.9867 - val_loss: 0.9482 - val_accuracy: 0.7947
# Epoch 72/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0274 - accuracy: 0.9867 - val_loss: 0.9515 - val_accuracy: 0.7969
# Epoch 73/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0287 - accuracy: 0.9858 - val_loss: 0.9583 - val_accuracy: 0.7947
# Epoch 74/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 0.9810 - val_loss: 0.9638 - val_accuracy: 0.7925
# Epoch 75/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0281 - accuracy: 0.9858 - val_loss: 0.9673 - val_accuracy: 0.7947
# Epoch 76/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0273 - accuracy: 0.9867 - val_loss: 0.9711 - val_accuracy: 0.7947
# Epoch 77/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0275 - accuracy: 0.9848 - val_loss: 0.9727 - val_accuracy: 0.7925
# Epoch 78/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0288 - accuracy: 0.9858 - val_loss: 0.9773 - val_accuracy: 0.7925
# Epoch 79/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0282 - accuracy: 0.9839 - val_loss: 0.9848 - val_accuracy: 0.7881
# Epoch 80/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0280 - accuracy: 0.9839 - val_loss: 0.9821 - val_accuracy: 0.7969
# Epoch 81/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0275 - accuracy: 0.9858 - val_loss: 0.9877 - val_accuracy: 0.7925
# Epoch 82/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0277 - accuracy: 0.9839 - val_loss: 0.9898 - val_accuracy: 0.7925
# Epoch 83/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0272 - accuracy: 0.9858 - val_loss: 0.9943 - val_accuracy: 0.7969
# Epoch 84/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0277 - accuracy: 0.9839 - val_loss: 1.0008 - val_accuracy: 0.7947
# Epoch 85/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0271 - accuracy: 0.9848 - val_loss: 1.0016 - val_accuracy: 0.7947
# Epoch 86/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0271 - accuracy: 0.9848 - val_loss: 1.0054 - val_accuracy: 0.7925
# Epoch 87/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0270 - accuracy: 0.9858 - val_loss: 1.0097 - val_accuracy: 0.7947
# Epoch 88/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0271 - accuracy: 0.9848 - val_loss: 1.0130 - val_accuracy: 0.7947
# Epoch 89/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0276 - accuracy: 0.9810 - val_loss: 1.0154 - val_accuracy: 0.7969
# Epoch 90/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0271 - accuracy: 0.9858 - val_loss: 1.0197 - val_accuracy: 0.7947
# Epoch 91/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0270 - accuracy: 0.9839 - val_loss: 1.0212 - val_accuracy: 0.7925
# Epoch 92/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0273 - accuracy: 0.9858 - val_loss: 1.0253 - val_accuracy: 0.7925
# Epoch 93/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0270 - accuracy: 0.9858 - val_loss: 1.0271 - val_accuracy: 0.7925
# Epoch 94/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0271 - accuracy: 0.9858 - val_loss: 1.0330 - val_accuracy: 0.7925
# Epoch 95/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0271 - accuracy: 0.9829 - val_loss: 1.0394 - val_accuracy: 0.7925
# Epoch 96/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0267 - accuracy: 0.9886 - val_loss: 1.0401 - val_accuracy: 0.7925
# Epoch 97/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0273 - accuracy: 0.9858 - val_loss: 1.0433 - val_accuracy: 0.7925
# Epoch 98/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0275 - accuracy: 0.9858 - val_loss: 1.0464 - val_accuracy: 0.7925
# Epoch 99/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0273 - accuracy: 0.9867 - val_loss: 1.0518 - val_accuracy: 0.7903
# Epoch 100/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0268 - accuracy: 0.9839 - val_loss: 1.0487 - val_accuracy: 0.7925

# %%
yp = ann.predict(x_test)
yp[:5]
# Out:
# 16/16 [==============================] - 0s 2ms/step
# array([[7.2388452e-01],
#        [9.4098737e-04],
#        [9.9999905e-01],
#        [9.9848431e-01],
#        [9.9400127e-01]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79       271
#            1       0.75      0.78      0.77       232
#
#     accuracy                           0.78       503
#    macro avg       0.78      0.78      0.78       503
# weighted avg       0.78      0.78      0.78       503

# %%
from tensorflow.keras.layers import SimpleRNN

# define the model
model = Sequential()
model.add(Embedding(32000, 24, input_length=1716))#24--86
model.add(SimpleRNN(24, return_sequences=False)) #24--86
model.add(Dense(1, activation='sigmoid')) #2--86%

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) #optimizer='rmsprop' --86

# summarize the model
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 1716, 24)          768000
#
#  simple_rnn_1 (SimpleRNN)    (None, 24)                1176
#
#  dense_7 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 769,201
# Trainable params: 769,201
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Embedding
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# fit the model
model.fit(x_train,
         y_train,
         epochs=100, verbose=1,
         callbacks=[early_stop]
         )
# Out:
# Epoch 1/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4828
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 25s 489ms/step - loss: 0.6940 - accuracy: 0.4828
# Epoch 2/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6949 - accuracy: 0.4907
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 507ms/step - loss: 0.6949 - accuracy: 0.4907
# Epoch 3/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6943 - accuracy: 0.4954
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 504ms/step - loss: 0.6943 - accuracy: 0.4954
# Epoch 4/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6968 - accuracy: 0.4927
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 26s 550ms/step - loss: 0.6968 - accuracy: 0.4927
# Epoch 5/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4748
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 506ms/step - loss: 0.6937 - accuracy: 0.4748
# Epoch 6/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5013
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 25s 519ms/step - loss: 0.6935 - accuracy: 0.5013
# Epoch 7/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 500ms/step - loss: 0.6933 - accuracy: 0.5040
# Epoch 8/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4907
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 499ms/step - loss: 0.6935 - accuracy: 0.4907
# Epoch 9/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4927
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 494ms/step - loss: 0.6937 - accuracy: 0.4927
# Epoch 10/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 490ms/step - loss: 0.6939 - accuracy: 0.5000
# Epoch 11/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6944 - accuracy: 0.4695
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 494ms/step - loss: 0.6944 - accuracy: 0.4695
# Epoch 12/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4973
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 25s 526ms/step - loss: 0.6934 - accuracy: 0.4973
# Epoch 13/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5093
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 496ms/step - loss: 0.6936 - accuracy: 0.5093
# Epoch 14/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4914
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 27s 560ms/step - loss: 0.6934 - accuracy: 0.4914
# Epoch 15/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4808
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 495ms/step - loss: 0.6940 - accuracy: 0.4808
# Epoch 16/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4867
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 495ms/step - loss: 0.6936 - accuracy: 0.4867
# Epoch 17/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4854
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 499ms/step - loss: 0.6936 - accuracy: 0.4854
# Epoch 18/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5053
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 492ms/step - loss: 0.6934 - accuracy: 0.5053
# Epoch 19/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4854
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 26s 543ms/step - loss: 0.6935 - accuracy: 0.4854
# Epoch 20/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4907
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 509ms/step - loss: 0.6935 - accuracy: 0.4907
# Epoch 21/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6949 - accuracy: 0.5027
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 26s 538ms/step - loss: 0.6949 - accuracy: 0.5027
# Epoch 22/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5027
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 495ms/step - loss: 0.6934 - accuracy: 0.5027
# Epoch 23/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4847
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 496ms/step - loss: 0.6937 - accuracy: 0.4847
# Epoch 24/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5027
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 500ms/step - loss: 0.6939 - accuracy: 0.5027
# Epoch 25/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4901
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 501ms/step - loss: 0.6931 - accuracy: 0.4901
# Epoch 26/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4980
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 497ms/step - loss: 0.6938 - accuracy: 0.4980
# Epoch 27/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4940
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 500ms/step - loss: 0.6935 - accuracy: 0.4940
# Epoch 28/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4907
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 496ms/step - loss: 0.6937 - accuracy: 0.4907
# Epoch 29/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5080
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 26s 538ms/step - loss: 0.6933 - accuracy: 0.5080
# Epoch 30/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4808
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 497ms/step - loss: 0.6933 - accuracy: 0.4808
# Epoch 31/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.5053
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 504ms/step - loss: 0.6938 - accuracy: 0.5053
# Epoch 32/100
# 48/48 [==============================] - ETA: 0s - loss: 0.7027 - accuracy: 0.4920
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 503ms/step - loss: 0.7027 - accuracy: 0.4920
# Epoch 33/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 0.4801
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 500ms/step - loss: 0.6950 - accuracy: 0.4801
# Epoch 34/100
# 48/48 [==============================] - ETA: 0s - loss: 0.7009 - accuracy: 0.4808
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 500ms/step - loss: 0.7009 - accuracy: 0.4808
# Epoch 35/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6976 - accuracy: 0.5040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 500ms/step - loss: 0.6976 - accuracy: 0.5040
# Epoch 36/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6967 - accuracy: 0.5133
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 495ms/step - loss: 0.6967 - accuracy: 0.5133
# Epoch 37/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6947 - accuracy: 0.5219
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 498ms/step - loss: 0.6947 - accuracy: 0.5219
# Epoch 38/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.4954
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 26s 536ms/step - loss: 0.6957 - accuracy: 0.4954
# Epoch 39/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6970 - accuracy: 0.5007
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 497ms/step - loss: 0.6970 - accuracy: 0.5007
# Epoch 40/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.5119
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 495ms/step - loss: 0.6955 - accuracy: 0.5119
# Epoch 41/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5358
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 495ms/step - loss: 0.6933 - accuracy: 0.5358
# Epoch 42/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6964 - accuracy: 0.4993
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 496ms/step - loss: 0.6964 - accuracy: 0.4993
# Epoch 43/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6974 - accuracy: 0.4901
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 497ms/step - loss: 0.6974 - accuracy: 0.4901
# Epoch 44/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6914 - accuracy: 0.5245
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 493ms/step - loss: 0.6914 - accuracy: 0.5245
# Epoch 45/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6966 - accuracy: 0.5066
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 494ms/step - loss: 0.6966 - accuracy: 0.5066
# Epoch 46/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6954 - accuracy: 0.4920
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 24s 492ms/step - loss: 0.6954 - accuracy: 0.4920
# Epoch 47/100
# 48/48 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5093
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 48/48 [==============================] - 25s 528ms/step - loss: 0.6934 - accuracy: 0.5093
# Epoch 48/100
# 16/48 [=========>....................] - ETA: 15s - loss: 0.6941 - accuracy: 0.5078
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-e9b0fa873280> in <module>
#      10
#      11 # fit the model
# ---> 12 model.fit(x_train,
#      13          y_train,
#      14          epochs=100, verbose=1,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
c_report(test_labels, preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-92a13417cd03> in <module>
# ----> 1 c_report(test_labels, preds)
#
# NameError: name 'c_report' is not defined

# %%
x_train.shape
# Out:
# (1508, 1716)

# %%
# For conv1D dimentionality should be 187X1 where 187 is number of features and 1 = 1D Dimentionality of data
x_train = x_train.reshape(len(x_train),x_train.shape[1],1)
x_test = x_test.reshape(len(x_test),x_test.shape[1],1)

# %%
x_train.shape

# %%
from keras.models import Sequential
from keras.layers import Dense # for fully connected layers dense will be used
from keras.layers import Conv1D, MaxPooling1D, Flatten
from keras.optimizers import Adam

# avoid overfitting by normalizing the samples
from tensorflow.keras.layers import BatchNormalization
#from keras.layers.normalization import BatchNormalization

# %%
def build_model():
    model = Sequential()
    
    # Filters = Units in Dense Total number of Neurons
    # Padding = 'same' , zero-padding, Add zero pixels all around input data
    model.add(Conv1D(filters = 64, kernel_size = 6, activation='relu', padding = 'same', input_shape = (1716, 1))) #we pass individual values hence not 100000,187,1
    
    # Normalization to avoid overfitting
    model.add(BatchNormalization())
    
    # Pooling 
    model.add(MaxPooling1D(pool_size=(3), strides = (2), padding = 'same'))

    model.add(Conv1D(filters = 64, kernel_size = 6, activation='relu', padding = 'same'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=(3), strides = (2), padding = 'same'))

    model.add(Conv1D( filters = 64, kernel_size = 6, activation='relu', padding = 'same'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=(3), strides = (2), padding = 'same'))

    # Flatten 
    model.add(Flatten())

    # Fully connected layer
    # input layer
    model.add(Dense(units = 20, activation='relu'))
    
    # Hidden Layer
    model.add(Dense(units = 20, activation='relu'))
    
    # Output Layer
    model.add(Dense(units = 1, activation='softmax'))

    # loss = 'categorical_crossentropy'
    model.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = build_model()

# %%
# This is for one sample, i.e. one row
model.summary()

# %%
history = model.fit(x_train, y_train, epochs = 10, batch_size = 20, validation_data=(x_test, y_test))

# %%
# evaluate ECG Test Data
model.evaluate(x_test, y_test)

# %%
#Importing the libraries  
import numpy as nm  
import matplotlib.pyplot as mtp  
import pandas as pd

# %%
# Splitting the dataset into the Training set and Test set  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 1)

# %%
 #Feature Scaling  
from sklearn.preprocessing import StandardScaler  
sc = StandardScaler()  
x_train = sc.fit_transform(x_train)  
x_test = sc.transform(x_test)

# %% [markdown]
# rnn

# %%
from tensorflow.keras.layers import SimpleRNN

# define the model
model = Sequential()
model.add(Embedding(vocab_size, 24, input_length=max_length))#24--86
model.add(SimpleRNN(24, return_sequences=False)) #24--86
model.add(Dense(2, activation='sigmoid')) #2--86%

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) #optimizer='rmsprop' --86

# summarize the model
print(model.summary())
